# %%
from tools1 import *

# %%
##CONNECT_TO_MAIL_INBOX##
##GET_LAST_Email###
password='202JMT4223'

user ='fadi.haboubi@esprit.tn'
email=get_last_mail(user,password)
email['From']
# Out:
# 'fadi habouba <fadhabouba580@gmail.com>'

# %%
#detecting img in email_signature
img=get_logo_signature(email)
img
# Out:
# 0
# 1
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1277x933>

# %%
# we are using Eden Api https://www.edenai.co/
# go get yourself free key
key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiNTBlOGQ5YWUtMmExNC00YTA1LTgzZWMtMWY0ZThhMDczMDIwIiwidHlwZSI6ImFwaV90b2tlbiJ9.DoMaXPi7Sd7I-LpzwNQ4bd7Sd7r_4rtT1aGziC03uSs"

# %%
info=logo_det_api1(img,key)

# %%
info
# Out:
# {'statue': True,
#  'name': 'Adidas',
#  'score': '0.87094605',
#  'description': 'high'}
